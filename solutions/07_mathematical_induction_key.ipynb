# %% [markdown]
# # Mathematical Induction Practice Solutions
#
# Worked solutions for the practice problems in [`07_mathematical_induction.ipynb`](../07_mathematical_induction.ipynb).

# %% [markdown]
# ### Problem 1: Sum of Squares
#
# Verify computationally that $\sum_{i=1}^{n} i^2 = \dfrac{n(n+1)(2n+1)}{6}$ for all $n$ from 1 to 20. (Then you would prove it by induction.)

# %%
def lhs(n):
    return sum(i * i for i in range(1, n + 1))

def rhs(n):
    return n * (n + 1) * (2 * n + 1) // 6

print("identity holds for n = 1..20:", all(lhs(n) == rhs(n) for n in range(1, 21)))
# Out:
# identity holds for n = 1..20: True

# %% [markdown]
# ### Problem 2: Sum of Even Numbers
#
# Verify that $\sum_{i=1}^{n} 2i = n(n+1)$ for $n = 1$ to $20$.

# %%
print("holds for n = 1..20:",
      all(sum(2 * i for i in range(1, n + 1)) == n * (n + 1) for n in range(1, 21)))
# Out:
# holds for n = 1..20: True

# %% [markdown]
# ### Problem 3: A Parity Result
#
# Verify that $n^2 + n$ is even for every integer $n$ from 0 to 30.

# %%
print("n^2 + n is even for n = 0..30:",
      all((n * n + n) % 2 == 0 for n in range(31)))
# Out:
# n^2 + n is even for n = 0..30: True

# %% [markdown]
# ### Problem 4: Geometric Sum of Powers of 2
#
# Verify that $1 + 2 + 4 + \cdots + 2^{n-1} = 2^n - 1$ for $n = 1$ to $15$.

# %%
def lhs(n):
    return sum(2**i for i in range(n))      # 2^0 + ... + 2^{n-1}

print("holds for n = 1..15:", all(lhs(n) == 2**n - 1 for n in range(1, 16)))
# Out:
# holds for n = 1..15: True
